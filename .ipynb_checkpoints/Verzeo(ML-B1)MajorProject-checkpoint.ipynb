# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict

# %% [markdown]
# #### Now we will be loading and reading the provided dataset for the problem:

# %%
data = pd.read_excel("Data_Train.xlsx")
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# **Extracting basic information about our dataset:**
#    * Columns
#    * Total Entries
#    * Data types of columns
#    * Describe of the integer columns
#    * Missing values

# %%
data.shape
# Out:
# (6019, 12)

# %%
data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
print(data.isna().any())
print("\n")
print(data.info())
print("\n")
data.describe()
# Out:
# Name                 False
# Location             False
# Year                 False
# Kilometers_Driven    False
# Fuel_Type            False
# Transmission         False
# Owner_Type           False
# Mileage               True
# Engine                True
# Power                 True
# Seats                 True
# Price                False
# dtype: bool
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 564.4+ KB
# None
#               Year  Kilometers_Driven        Seats        Price
# count  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   2013.358199       5.873838e+04     5.278735     9.479468
# std       3.269742       9.126884e+04     0.808840    11.187917
# min    1998.000000       1.710000e+02     0.000000     0.440000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000     5.640000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %% [markdown]
# **Columns with missing values are ['Mileage', 'Engine', 'Power', 'Seats']**
#
# Also these columns are in categorical form we'll be converting them to numerical variables for EDA.

# %% [markdown]
# **From this we also see that the minimum value of seats is 0 which isn't physically feasbile so its an error in the data.**

# %%
#Converting columns to numeric value
data['Mileage'] = data['Mileage'].str.split().str.get(0)
data['Mileage'] = data['Mileage'].apply(pd.to_numeric)

#Filling null and NAN values in Power column

data['Power'] = data['Power'].str.split().str.get(0)
data['Power'] = data['Power'].replace('null', np.nan)
data['Power'] = data['Power'].replace('nan', np.nan)
data['Power'] = data['Power'].apply(pd.to_numeric)


data['Engine'] = data['Engine'].str.split().str.get(0)
data['Engine'] = data['Engine'].replace('nan',np.nan)
data['Engine'] = data['Engine'].apply(pd.to_numeric)

data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   float64
#  8   Engine             5983 non-null   float64
#  9   Power              5876 non-null   float64
#  10  Seats              5977 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 564.4+ KB
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  6019.000000       6.019000e+03  6017.000000  5983.000000  5876.000000
# mean   2013.358199       5.873838e+04    18.134961  1621.276450   113.253050
# std       3.269742       9.126884e+04     4.582289   601.355233    53.874957
# min    1998.000000       1.710000e+02     0.000000    72.000000    34.200000
# 25%    2011.000000       3.400000e+04    15.170000  1198.000000    75.000000
# 50%    2014.000000       5.300000e+04    18.150000  1493.000000    97.700000
# 75%    2016.000000       7.300000e+04    21.100000  1984.000000   138.100000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   560.000000
#
#              Seats        Price
# count  5977.000000  6019.000000
# mean      5.278735     9.479468
# std       0.808840    11.187917
# min       0.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.640000
# 75%       5.000000     9.950000
# max      10.000000   160.000000

# %% [markdown]
# **We see that minimum values of Mileage and Seats are zero which is not possible for a car,most likely missing values were replaced by 0 in those columns.**

# %%
data.replace(0,np.nan,inplace=True)
data[data.Mileage == 0]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, Price]
# Index: []

# %%
data.reset_index(drop=True)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          CNG       Manual      First    26.60   998.0   58.16    5.0   1.75
# 1       Diesel       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2       Petrol       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3       Diesel       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4       Diesel    Automatic     Second    15.20  1968.0  140.80    5.0  17.74
# ...        ...          ...        ...      ...     ...     ...    ...    ...
# 6014    Diesel       Manual      First    28.40  1248.0   74.00    5.0   4.75
# 6015    Diesel       Manual      First    24.40  1120.0   71.00    5.0   4.00
# 6016    Diesel       Manual     Second    14.00  2498.0  112.00    8.0   2.90
# 6017    Petrol       Manual      First    18.90   998.0   67.10    5.0   2.65
# 6018    Diesel       Manual      First    25.44   936.0   57.60    5.0   2.50
#
# [6019 rows x 12 columns]

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  6019.000000       6.019000e+03  5949.000000  5983.000000  5876.000000
# mean   2013.358199       5.873838e+04    18.342252  1621.276450   113.253050
# std       3.269742       9.126884e+04     4.175475   601.355233    53.874957
# min    1998.000000       1.710000e+02     6.400000    72.000000    34.200000
# 25%    2011.000000       3.400000e+04    15.300000  1198.000000    75.000000
# 50%    2014.000000       5.300000e+04    18.200000  1493.000000    97.700000
# 75%    2016.000000       7.300000e+04    21.100000  1984.000000   138.100000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   560.000000
#
#              Seats        Price
# count  5976.000000  6019.000000
# mean      5.279618     9.479468
# std       0.806019    11.187917
# min       2.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.640000
# 75%       5.000000     9.950000
# max      10.000000   160.000000

# %%
data.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage               70
# Engine                36
# Power                143
# Seats                 43
# Price                  0
# dtype: int64

# %% [markdown]
# **Checking if there is any duplicate data that can be dropped:**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Cleaning Data:

# %% [markdown]
# **Removing missing values (NANs)**

# %%
data.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage               70
# Engine                36
# Power                143
# Seats                 43
# Price                  0
# dtype: int64

# %%
data[data.Fuel_Type == 'Electric']
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type  Mileage  Engine  Power  Seats  Price
# 4446    Automatic      First      NaN    72.0   41.0    5.0  13.00
# 4904    Automatic      First      NaN  1798.0   73.0    5.0  12.75

# %% [markdown]
# *We can see that For Electric car the mileage column holds a NaN value which makes sense,we can replace those with 0 or some other distinguishing value*

# %%
data.loc[data.Fuel_Type =='Electric'] = data.loc[data.Fuel_Type =='Electric'].replace(np.nan,0) 
data[data.Fuel_Type == 'Electric']
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type  Mileage  Engine  Power  Seats  Price
# 4446    Automatic      First      0.0    72.0   41.0    5.0  13.00
# 4904    Automatic      First      0.0  1798.0   73.0    5.0  12.75

# %% [markdown]
# **We will split the name into brand,model,version**

# %%
# print(str(data.Name).split())
#data['Brand'] = data.Name.str.split().str.get(0)
data['Brand']=pd.DataFrame(data['Name'].apply(lambda x: x.split(' ',2)))
data[['Brand','Model','Version']] = pd.DataFrame(data.Brand.tolist(),index=data.index)
data = data[['Brand','Model','Version']+data.columns[:-3].tolist()]
data.head()
# data['Brand'].value_counts()
# Out:
#      Brand   Model                  Version                              Name  \
# 0   Maruti   Wagon                R LXI CNG            Maruti Wagon R LXI CNG
# 1  Hyundai   Creta       1.6 CRDi SX Option  Hyundai Creta 1.6 CRDi SX Option
# 2    Honda    Jazz                        V                      Honda Jazz V
# 3   Maruti  Ertiga                      VDI                 Maruti Ertiga VDI
# 4     Audi      A4  New 2.0 TDI Multitronic   Audi A4 New 2.0 TDI Multitronic
#
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0      Mumbai  2010              72000       CNG       Manual      First
# 1        Pune  2015              41000    Diesel       Manual      First
# 2     Chennai  2011              46000    Petrol       Manual      First
# 3     Chennai  2012              87000    Diesel       Manual      First
# 4  Coimbatore  2013              40670    Diesel    Automatic     Second
#
#    Mileage  Engine   Power  Seats  Price
# 0    26.60   998.0   58.16    5.0   1.75
# 1    19.67  1582.0  126.20    5.0  12.50
# 2    18.20  1199.0   88.70    5.0   4.50
# 3    20.77  1248.0   88.76    7.0   6.00
# 4    15.20  1968.0  140.80    5.0  17.74

# %%
# Excpet for the brand Land Rover rest of the name splits are accurate
data[data.Brand == 'Land'].head(2)
# Out:
#    Brand  Model                Version                              Name  \
# 13  Land  Rover  Range Rover 2.2L Pure  Land Rover Range Rover 2.2L Pure
# 14  Land  Rover    Freelander 2 TD4 SE    Land Rover Freelander 2 TD4 SE
#
#    Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 13    Delhi  2014              72000    Diesel    Automatic      First
# 14     Pune  2012              85000    Diesel    Automatic     Second
#
#     Mileage  Engine  Power  Seats  Price
# 13     12.7  2179.0  187.7    5.0   27.0
# 14      NaN  2179.0  115.0    5.0   17.5

# %%
#Fixing the Land Rover Brand name
def Corrector(x):
    x.Brand = 'Land Rover'
    if 'Range Rover' not in x.Version:
        x.Model,x.Version = x.Version.split(" ",1)
    else:
        x.Model = 'Range Rover'
        x.Version = x.Version.split('Range Rover',1)[1]
    return x

data.loc[data.Brand == 'Land'] = data.loc[data.Brand == 'Land'].apply(lambda row: Corrector(row),axis =1).copy()

# %%
data[data.Brand == 'Land Rover'].head(2)
# Out:
#          Brand        Model     Version                              Name  \
# 13  Land Rover  Range Rover   2.2L Pure  Land Rover Range Rover 2.2L Pure
# 14  Land Rover   Freelander    2 TD4 SE    Land Rover Freelander 2 TD4 SE
#
#    Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 13    Delhi  2014              72000    Diesel    Automatic      First
# 14     Pune  2012              85000    Diesel    Automatic     Second
#
#     Mileage  Engine  Power  Seats  Price
# 13     12.7  2179.0  187.7    5.0   27.0
# 14      NaN  2179.0  115.0    5.0   17.5

# %% [markdown]
# **Checking Null Values**

# %%
data.isnull().sum()
# Out:
# Brand                  0
# Model                  0
# Version                0
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage               68
# Engine                36
# Power                143
# Seats                 43
# Price                  0
# dtype: int64

# %% [markdown]
# ### Filling NaN values

# %%
# Filling NaN in the columns by looking for missing values of same brand and model of the car in a different year.

# %%
for i in ['Power','Engine','Seats','Mileage']:

    a = data.groupby(['Brand','Model','Year'])[i].agg('mean')
    a = pd.DataFrame(a)

    a.reset_index(col_level=i,inplace=True)
    
    a.replace(0.0,np.nan,inplace = True)
    a.fillna(method='ffill',inplace=True)

    a.drop(columns ='Year',inplace=True)

    a = a.set_index(['Brand','Model'])
    a=a.to_dict()
    
    if(i=='Power'):
        p = a
    elif(i=='Mileage'):
        m = a
    elif(i=='Engine'):
        e = a 
    else:
        s =  a

def fill_Power(x):
    if (x.Brand,x.Model) in p['Power'].keys():
        x.Power = p['Power'][(x.Brand,x.Model)]
    return x
def fill_mileage(x):
    if (x.Brand,x.Model) in m['Mileage'].keys():
        x.Mileage = m['Mileage'][(x.Brand,x.Model)]
    return x
def fill_seats(x):
    if (x.Brand,x.Model) in s['Seats'].keys():
        x.Seats = s['Seats'][(x.Brand,x.Model)]
    return x
def fill_Engine(x):
    if (x.Brand,x.Model) in e['Engine'].keys():
        x.Engine = e['Engine'][(x.Brand,x.Model)]
    return x

# %%
data.loc[data.Mileage.isnull()] = data.loc[data.Mileage.isnull()].apply(lambda x: fill_mileage(x),axis=1,result_type='expand')

data.loc[data.Power.isnull()] = data.loc[data.Power.isnull()].apply(lambda x: fill_Power(x),axis=1,result_type='expand')

data.loc[data.Seats.isnull()] = data.loc[data.Seats.isnull()].apply(lambda x: fill_seats(x),axis=1,result_type='expand')

data.loc[data.Engine.isnull()] = data.loc[data.Engine.isnull()].apply(lambda x: fill_Engine(x),axis=1,result_type='expand')

# %%
data.isnull().sum()
# Out:
# Brand                0
# Model                0
# Version              0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# #### Filter bad data:

# %%
# Filter bad data
dataClean = data[
    (data["Year"].between(2004, 2019, inclusive=True)) &
    (data["Power"].between(100, 600, inclusive=True)) &
    (data["Price"].between(3, 120, inclusive=True)) &
    (data["Kilometers_Driven"].between(100, 350000, inclusive=True))]

# %%
dataClean.reset_index(drop = True)
# Out:
#               Brand     Model                  Version  \
# 0           Hyundai     Creta       1.6 CRDi SX Option
# 1              Audi        A4  New 2.0 TDI Multitronic
# 2            Toyota    Innova      Crysta 2.8 GX AT 8S
# 3        Volkswagen     Vento       Diesel Comfortline
# 4            Maruti      Ciaz                     Zeta
# ...             ...       ...                      ...
# 2633  Mercedes-Benz   M-Class               ML 320 CDI
# 2634        Porsche  Panamera                   Diesel
# 2635         Toyota     Camry                   Hybrid
# 2636          Skoda    Superb               3.6 V6 FSI
# 2637         Toyota    Innova    2.5 V Diesel 7-seater
#
#                                      Name    Location  Year  \
# 0        Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1         Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 2       Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 3     Volkswagen Vento Diesel Comfortline        Pune  2013
# 4                        Maruti Ciaz Zeta       Kochi  2018
# ...                                   ...         ...   ...
# 2633     Mercedes-Benz M-Class ML 320 CDI      Mumbai  2009
# 2634              Porsche Panamera Diesel   Hyderabad  2013
# 2635                  Toyota Camry Hybrid      Mumbai  2015
# 2636              Skoda Superb 3.6 V6 FSI   Hyderabad  2009
# 2637  Toyota Innova 2.5 V Diesel 7-seater  Coimbatore  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0                 41000    Diesel       Manual      First    19.67  1582.0
# 1                 40670    Diesel    Automatic     Second    15.20  1968.0
# 2                 36000    Diesel    Automatic      First    11.36  2755.0
# 3                 64430    Diesel       Manual      First    20.54  1598.0
# 4                 25692    Petrol       Manual      First    21.56  1462.0
# ...                 ...       ...          ...        ...      ...     ...
# 2633             102002    Diesel    Automatic      First     8.70  2987.0
# 2634              40000    Diesel    Automatic     Second    17.85  2967.0
# 2635              33500    Petrol    Automatic      First    19.16  2494.0
# 2636              53000    Petrol    Automatic      First    14.67  3597.0
# 2637              45004    Diesel       Manual      First    12.80  2494.0
#
#        Power  Seats  Price
# 0     126.20    5.0  12.50
# 1     140.80    5.0  17.74
# 2     171.50    8.0  17.50
# 3     103.60    5.0   5.20
# 4     103.25    5.0   9.95
# ...      ...    ...    ...
# 2633  224.34    5.0  10.75
# 2634  300.00    4.0  45.00
# 2635  158.20    5.0  19.75
# 2636  262.60    5.0   4.75
# 2637  102.00    7.0   9.48
#
# [2638 rows x 15 columns]

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  6019.000000       6.019000e+03  6019.000000  6019.000000  6019.000000
# mean   2013.358199       5.873838e+04    18.301608  1620.534973   112.725654
# std       3.269742       9.126884e+04     4.180116   601.114545    53.968716
# min    1998.000000       1.710000e+02     0.000000    72.000000    34.200000
# 25%    2011.000000       3.400000e+04    15.290000  1198.000000    75.000000
# 50%    2014.000000       5.300000e+04    18.150000  1493.000000    93.700000
# 75%    2016.000000       7.300000e+04    21.100000  1984.000000   138.100000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   560.000000
#
#              Seats        Price
# count  6019.000000  6019.000000
# mean      5.277953     9.479468
# std       0.803778    11.187917
# min       2.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.640000
# 75%       5.000000     9.950000
# max      10.000000   160.000000
